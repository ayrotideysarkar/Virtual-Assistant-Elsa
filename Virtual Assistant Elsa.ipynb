# %% [markdown]
# ### NECESSARY PYTHON LIBRARIES ###

# %%
import speech_recognition 
import pyttsx3
import pywhatkit
import datetime
import wikipedia
import pyjokes
import os
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ### INSTALLATION  COMMAND ###

# %%
#FOR SPEECHRECOGNITION: pip install SpeechRecognition

# %%
#FOR PYTTSX3 : pip install pyttsx3

# %%
#FOR PYWHATKIT : pip install pywhatkit

# %%
#FOR DATETIME : pip install datetime

# %%
#FOR WIKIPEDIA : pip install wikipedia

# %%
#FOR PYJOKES : pip install pyjokes

# %%
#FOR WEBBROWSER : pip install webbrowser

# %%
import pyttsx3
import speech_recognition as sr
import webbrowser
import pywhatkit
import datetime
import wikipedia
import os
from bs4 import BeautifulSoup
import requests
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.3'
}


def takeCommand():

	r = sr.Recognizer()


	with sr.Microphone() as source:
		print('Listening....')


		r.pause_threshold = 0.7
		audio = r.listen(source)


		try:
			print("Recognizing....")


			Query = r.recognize_google(audio, language='en-in')
			print("the command is printed=", Query)
			
		except Exception as e:
			print(e)
			print("Say that again sir")
			return "None"
		return Query

def speak(audio):

	engine = pyttsx3.init()

	voices = engine.getProperty('voices')


	engine.setProperty('voice', voices[1].id)

	engine.say(audio)


	engine.runAndWait()

def tellDay():


	day = datetime.datetime.today().weekday() + 1


	Day_dict = {1: 'Monday', 2: 'Tuesday',
				3: 'Wednesday', 4: 'Thursday',
				5: 'Friday', 6: 'Saturday',
				7: 'Sunday'}

	if day in Day_dict.keys():
		day_of_the_week = Day_dict[day]
		print(day_of_the_week)
		speak("The day is " + day_of_the_week)

def weather(city):
    city = city.replace(" ", "+")
    res = requests.get(        
        f'https://www.google.com/search?q={city}+weather+report&rlz=1C1VDKB_enIN942IN942&oq={city}+weather+report&aqs=chrome..69i57j0i457i512j0i512l8.4910j1j7&sourceid=chrome&ie=UTF-8', headers=headers)
    soup = BeautifulSoup(res.text, 'html.parser')
    location = soup.select('#wob_loc')[0].getText().strip()
    time = soup.select('#wob_dts')[0].getText().strip()
    info = soup.select('#wob_dc')[0].getText().strip()
    weather = soup.select('#wob_tm')[0].getText().strip()
    return(location,time,info,weather)

def tellTime():

	time = str(datetime.datetime.now())
	print(time)
	hour = time[11:13]
	min = time[14:16]
	speak("The time is sir" + hour + "Hours and" + min + "Minutes")	

def Hello():

	speak("hello sir I am your desktop assistant Elsa.Tell me how may I help you")


def Take_query():


	Hello()

	while(True):

		query = takeCommand().lower()
		if "open geeksforgeeks" in query:
			speak("Opening GeeksforGeeks ")
			webbrowser.open("www.geeksforgeeks.com")
			continue
            
		elif "open google" in query:
			speak("Opening Google ")
			webbrowser.open("www.google.com")
			continue
            
		elif "open wikipedia" in query:
			speak("Opening wikipedia ")
			webbrowser.open("https://www.wikipedia.org/")
			continue
            
		elif "open football news" in query:
			speak("Opening Sports Football News ")
			webbrowser.open("https://www.skysports.com/football")
			continue

		elif "open formula 1 news" in query:
			speak("Opening Sports F1 News... ")
			webbrowser.open("https://www.skysports.com/f1")
			continue

		elif "open cricket news" in query:
			speak("Opening Sports cricket News... ")
			webbrowser.open("https://www.skysports.com/cricket")
			continue

		elif "open olympics news" in query:
			speak("Opening Sports Olympics News ")
			webbrowser.open("https://www.skysports.com/olympics")
			continue
            
		elif "open golf news" in query:
			speak("Opening Sports Golf News ")
			webbrowser.open("https://www.skysports.com/golf")
			continue

		elif "open tennis news" in query:
			speak("Opening Sports Tennis News ")
			webbrowser.open("https://www.skysports.com/tennis")
			continue

		elif "open boxing news" in query:
			speak("Opening Sports Boxing News ")
			webbrowser.open("https://www.skysports.com/boxing")
			continue
            
		elif 'play' in query:
			song = query.replace('play', '')
			print('playing '+ song)
			speak('playing'+ song)
			pywhatkit.playonyt(song)
			continue
            
		elif "tell me story" in query:
			speak("which story you want to listen? story 1, story 2 or story 3?")
			continue
		elif "story 1" in query:
			speak("the title of the story is  THE ROYAL PRISONER . summary , I wasn't suppose to fall in love with him. Because falling in love with him, had me experiencing something much worse than death. Death. It is suppose to be peaceful, right? I guess none of us can actually say, until we have experienced it ourselves. But then again, who would of thought that falling deeply in love with someone, would end up with me experiencing something much worse than death. And definitely not peaceful. ----- He was a ruthless monster sent to kill me. A highly trained hunter. A man who made me believe him. Made me trust him. And, made me love him. Twice. Stupid, I know. That however, was my first, second and last mistake I would ever make. But just because I mention the word love, doesn't mean this is a love story. Like I said, he was a monster that was sent to kill me. And that's just what he did.for full story i am redirecting to  THE ROYAL PRISONER")
			webbrowser.open("https://www.inkitt.com/stories/romance/291255?utm_source=shared_web via")
			continue
		elif "story 2" in query:
			speak("the title of the story is  HER NEW FAMILY . summary ,I have finally finished high-school. My two friends and I decided to go on a small trip kinda like a little congratulations to ourselves but things go horribly wrong and our car ends up crashing leaving us stranded on the side of the road. We decided to walk, we finally come up on a house and the family seems normal but something very sinister hides behind thier kind eyes. They drag me away to a mountain where the rest of the families live and it's all very different than the world I'm used too. My name is Elizabeth and I guess this is my new family? for  full story i am redirecting to HER NEW FAMILY")
			webbrowser.open("https://www.inkitt.com/stories/horror/779445?utm_source=shared_web")            
			continue
            
		elif " tell me jokes" in query:
			joke=pyjokes.get_jokes(language='en', category='all')
			speak(joke)
			exit()
			continue
        

		elif "take me to story world" in query:
			speak("please tell me which website u want to choose")
			continue
            
		elif "inkit" in query:
			webbrowser.open("https://www.inkitt.com//")
			continue
		elif "open manga" in query:
			webbrowser.open("https://www.viz.com/read")
			continue
            
		elif "open audible" in query:
			webbrowser.open("https://www.audible.in/")
			continue

            
		elif "which day it is" in query:
			tellDay()
			continue

		elif "tell me the time" in query:
			tellTime()
			continue
            
		elif "open Story" in query:
			speak("Checking the Stories ")
			query = query.replace("bedtimeshortstories", "")
			result = bedtimeshortstories.summary(query, sentences=4)
			speak("According to BedtimeShortStories")
			speak(result)

		elif 'how are you'in query or 'whats up' in query:
			print(">>I was doing great, before you asked for my assistance. Now i think I have a headache.")
			speak("I was doing great, before you asked for my assistance. Now i think I have a headache.")
			continue

		elif "bye" in query:
			speak("Bye. stay safe and stay at home !")
			return 0

		elif "tell me your name" in query:
			speak("I am Elsa. Your deskstop Assistant . Invented by group 7")

		elif"weather" in query:
			speak("Tell me the Name of City")
			city=takeCommand().lower()
			print(city)
			speak("checking the weather")
			val=weather(city)
			speak(f"Currentyly the temperature is {val[3]} degree celcius in {val[0]}")
			print(f"Currentyly the temperature is {val[3]} degree celcius in {val[0]}")
			speak(f"and its {val[2]} and the time is {val[1]}")
			print(f"and its {val[2]} and the time is {val[1]}")
			print(val[3]) 
			speak("have a nice day")
            
		elif 'song' in query:
			music_dir = 'D:\songs'
			songs = os.listdir(music_dir)
			print(songs)
			os.startfile(os.path.join(music_dir, songs[0]))
			speak("music is being played")
			continue

		elif"media" in query:
			speak("which social media  facebook  whatsapp  instagram  youtube   twitter  linkdin  github or tinder")
			media=takeCommand().lower()          
			if "youtube" in media:
				webbrowser.open("https://www.youtube.com/")
				continue
                
			elif "facebook" in media:
				print("coming in facebook")
				webbrowser.open("https://www.facebook.com/")
				continue
 
			elif "instagram" in media:
				print("coming in instagram")
				webbrowser.open("https://www.instagram.com/")
				continue

			elif "linkdin" in media:
				print("coming in linkdin")
				webbrowser.open("https://www.linkedin.com")
				continue
                
			elif "twitter" in media:
				print("coming in twitter")
				webbrowser.open("twitter.com")
				continue
                
			elif "whatsapp" in media:
				print("coming in whatsapp")
				webbrowser.open("whatsapp.com")
				continue
                
			elif "github" in media:
				print("coming in github")
				webbrowser.open("github.com")
				continue
                
			elif "tinder" in media:
				print("coming in tinder")
				webbrowser.open("https://tinder.com/")
				continue

		elif 'folder' in query:
			music_dir = 'D:\Placement_kit'
			files = os.listdir(music_dir)
			print(files)
			os.startfile(os.path.join(music_dir, files[0]))
			speak("folder is being opened...")
			continue


if __name__ == '__main__':

    Take_query()
else:
      exit()
# Out:
# Listening....
# Recognizing....
#
# Say that again sir
# Listening....
# Recognizing....
# the command is printed= media
# Listening....
# Recognizing....
# the command is printed= GitHub
# coming in github
# Listening....
